# %%
import sys
sys.path.insert(0, '/Users/xloxk/Downloads/sudoku/')

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

import sudoku
# %load_ext autoreload
# %autoreload 2

# %%
def display(img):
    if len(img.shape) == 2:
        plt.imshow(img, 'gray')
    else:
        img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
        plt.imshow(img)
    plt.axis('off')

# %%
raw_img = cv.imread('../assets/sudoku.png')
display(raw_img)

# %%
grid = sudoku.detector.extract_puzzle(raw_img)
print(grid)
# Out:
# [[0 0 0 6 0 4 7 0 0]
#  [7 0 6 0 0 0 0 0 9]
#  [0 0 0 0 0 5 0 8 0]
#  [0 7 0 0 2 0 0 9 3]
#  [8 0 0 0 0 0 0 0 5]
#  [4 3 0 0 1 0 0 7 0]
#  [0 5 0 2 0 0 0 0 0]
#  [3 0 0 0 0 0 2 0 8]
#  [0 0 2 3 0 1 0 0 0]]

# %%
puzzle = sudoku.solve.Puzzle.fromArray(grid)

# %%
red_puzzle = puzzle.reduce()
